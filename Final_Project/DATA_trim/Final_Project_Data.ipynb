# %%
library(geojson)
library(geojsonio)
library(httr)
library(stringr)
library("plyr")
# Out:
# Attaching package: ‘geojson’
#
# The following object is masked from ‘package:graphics’:
#
#     polygon
#
# Warning message:
# “package ‘geojsonio’ was built under R version 3.4.4”
# Attaching package: ‘geojsonio’
#
# The following object is masked from ‘package:base’:
#
#     pretty

# %%
library(jsonlite)
# Out:
# Attaching package: ‘jsonlite’
#
# The following object is masked from ‘package:geojsonio’:
#
#     validate

# %% [markdown]
# # 公園

# %%
park.files <- list.files("park/")

# %%
park.merge.df <- data.frame() 
park.total <- 0

# %%
park.merge.df
# Out:
# <0 x 0 matrix>

# %%
for(i in park.files){
    print(paste0("park/", i))
    park.df <- fromJSON(paste0("park/", i))
    park.total <- park.total + nrow(park.df)
    print(park.total)
    park.merge.df <- rbind(park.merge.df, park.df)
}
# Out:
# [1] "park/北投區"
# [1] 121
# [1] "park/大安區"
# [1] 186
# [1] "park/大同區"
# [1] 215
# [1] "park/南港區"
# [1] 269
# [1] "park/內湖區"
# [1] 358
# [1] "park/士林區"
# [1] 451
# [1] "park/松山區"
# [1] 494
# [1] "park/萬華區"
# [1] 522
# [1] "park/文山區"
# [1] 606
# [1] "park/信義區"
# [1] 666
# [1] "park/中山區"
# [1] 760
# [1] "park/中正區"
# [1] 782

# %%
nrow(park.merge.df)
# Out:
# [1] 782

# %%
park.merge.df
# Out:
#     Id                                   Image Name
# 1   16977272-41ff-4e65-a261-bd12496c36d5 NA    蜆仔港公園
# 2   399b976b-1ae1-4538-94cf-53ca0b190a82 NA    八仙公園
# 3   a728993c-4647-4533-a13f-956a73e3614c NA    北投139號綠地
# 4   899cdbd8-c886-4024-8912-3fa53cf5aa8a NA    北投138號綠地
# 5   8e1d8e31-977a-426d-a7b9-7235f5899509 NA    北投69號綠地
# 6   4e967885-d086-40d7-83d6-d027ab3fb90a NA    北投134號綠地
# 7   57e0bbb8-6b84-4772-9c4b-adb2c1a8fa35 NA    北投6號廣場
# 8   fedcb9e0-9c0a-44ff-ae5c-c6dc62ab3a76 NA    北投3號廣場
# 9   64eaab19-43e7-4e95-b35d-dccaee13b3ee NA    奇岩4號綠地
# 10  6175cc32-0ae1-4aad-b7ef-3ac83a0e0bc7 NA    磅空頂綠地
# 11  b1876d47-1b00-4eb0-83d2-bd828437c863 NA    文化綠地
# 12  1a17de42-c0c2-49eb-82e8-52fa4db5fb28 NA    北投192號綠地
# 13  122ac696-d903-479f-8cc6-8852e56c3da1 NA    北投191號綠地
# 14  f306d0c7-6d6d-43de-a1bd-76553018c30e NA    林投坑(二)綠地
# 15  dda6a5f0-dd7e-47f7-abfa-eb7d20520d2f NA    林投坑(一)綠地
# 16  4aee71aa-99ee-42e0-89e9-8d84bc43ffea NA    北投188號綠地
# ...

# %%
write.table(park.merge.df, file = "final_dataset/park.final.csv")

# %%
read.park <- read.csv("park.final.csv")
# Out:
# Warning message in file(file, "rt"):
# “無法開啟檔案 'park.final.csv' ：No such file or directory”
# Error in file(file, "rt"): 無法開啟連結
# Traceback:
#
# 1. read.csv("park.final.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %%
nrow(read.park)
# Out:
# [1] 782

# %% [markdown]
# # 捷運

# %%
mrt.file <- geojsonio::geojson_read("taipei_mrt.geojson", what = "sp")

# %%
mrt.df <- data.frame()

# %%
levels(mrt.file[[2]])
# Out:
#   [1] "板橋站出口1"         "板橋站出口2"         "板橋站出口3"
#   [4] "北門站出口1"         "北門站出口2"         "北門站出口3"
#   [7] "北投站出口"          "菜寮站出口1"         "菜寮站出口2"
#  [10] "菜寮站出口3"         "大安森林公園站出口1" "大安森林公園站出口2"
#  [13] "大安森林公園站出口3" "大安森林公園站出口4" "大安森林公園站出口5"
#  [16] "大安森林公園站出口6" "大安站出口1"         "大安站出口2"
#  [19] "大安站出口3"         "大安站出口4"         "大安站出口5"
#  [22] "大安站出口6"         "大湖公園站出口1"     "大湖公園站出口2"
#  [25] "大坪林站出口1"       "大坪林站出口2"       "大坪林站出口3"
#  [28] "大坪林站出口4"       "大橋頭站出口1"       "大橋頭站出口2"
#  [31] "大橋頭站出口3"       "大直站出口1"         "大直站出口2"
#  [34] "大直站出口3"         "丹鳳站出口1"         "丹鳳站出口2"
#  [37] "淡水站出口1"         "淡水站出口2"         "頂埔站出口1"
#  [40] "頂埔站出口2"         "頂埔站出口3"         "頂埔站出口4"
#  [43] "頂溪站出口1"         "頂溪站出口2"         "東湖站出口1"
#  [46] "東湖站出口2"         "東湖站出口3"         "東門站出口1"
#  [49] "東門站出口2"         "東門站出口3"         "東門站出口4"
#  [52] "東門站出口5"         "東門站出口6"         "東門站出口7"
#  [55] "東門站出口8"         "動物園站出口1"       "動物園站出口2"
# ...

# %%
mrt.file[[5]]
# Out:
#   [1] 24.95931 24.95931 24.95962 24.96039 25.06372 25.06367 25.06292 25.06089
#   [9] 25.04180 25.04135 25.04147 25.04177 25.04202 25.03351 25.03352 25.03324
#  [17] 25.03307 25.03286 25.03401 25.02615 25.02385 25.01855 25.00512 24.99938
#  [25] 24.99858 24.99817 24.99825 24.99795 25.08012 25.07958 25.07931 25.08517
#  [33] 25.08475 25.08448 25.08234 25.08202 25.08015 25.08007 25.07867 25.07841
#  [41] 25.08375 25.08364 25.08389 25.08367 25.07264 25.07253 25.06722 25.06711
#  [49] 25.06705 25.06000 25.05988 25.05585 25.05531 25.05512 25.05539 25.05524
#  [57] 25.05492 25.05474 25.05403 24.97168 24.97319 24.95788 24.96739 24.96799
#  [65] 24.97502 24.97691 24.98275 24.98205 24.98298 24.98354 24.99230 24.99307
#  [73] 24.99274 25.00137 25.00151 25.00221 25.00268 25.01451 25.01472 25.01541
#  [81] 25.01515 25.01962 25.02019 25.02118 25.02102 25.02076 25.02598 25.02550
#  [89] 25.02608 25.02642 25.02718 25.02754 25.02742 25.02706 25.02680 25.03303
# ...

# %%
lat.col <- c()

# %%
for( i in 1:length(mrt.file[[4]])) {
    lat.col <<- append(lat.col, mrt.file[[4]][i])
#     print(mrt.file[[4]][i])
}

# %%
lat.col
# Out:
#   [1] 121.4182 121.4190 121.4196 121.4201 121.5523 121.5513 121.5522 121.5440
#   [9] 121.5431 121.5434 121.5448 121.5451 121.5440 121.5419 121.5418 121.5423
#  [17] 121.5441 121.5437 121.5437 121.5436 121.5527 121.5586 121.5570 121.5577
#  [25] 121.5684 121.5734 121.5799 121.5794 121.5471 121.5468 121.5469 121.5552
#  [33] 121.5551 121.5561 121.5666 121.5671 121.5756 121.5747 121.5856 121.5845
#  [41] 121.5943 121.5946 121.6024 121.6022 121.6080 121.6072 121.6111 121.6112
#  [49] 121.6117 121.6158 121.6161 121.6169 121.6170 121.6182 121.6183 121.6170
#  [57] 121.6169 121.6182 121.6181 121.5303 121.5299 121.5376 121.5411 121.5418
#  [65] 121.5431 121.5426 121.5409 121.5416 121.5416 121.5414 121.5409 121.5415
#  [73] 121.5405 121.5389 121.5396 121.5392 121.5386 121.5344 121.5347 121.5341
#  [81] 121.5336 121.5286 121.5291 121.5278 121.5273 121.5277 121.5230 121.5234
#  [89] 121.5234 121.5231 121.5229 121.5223 121.5219 121.5219 121.5224 121.5178
# ...

# %%
mrt.df
# Out:
# <0 x 0 matrix>

# %%
# mrt.df[,"lng"]  <- mrt.file[[4]]
MRT_station_data <- cbind("station_name" = levels(mrt.file[[2]]),"lat" = mrt.file[[4]] , "lng" = mrt.file[[5]])

# %%
MRT_station_data
# Out:
#       station_name        lat        lng
#  [1,] 板橋站出口1         121.418218 24.959306
#  [2,] 板橋站出口2         121.419    24.95931
#  [3,] 板橋站出口3         121.4196   24.95962
#  [4,] 北門站出口1         121.4201   24.96039
#  [5,] 北門站出口2         121.552335 25.063717
#  [6,] 北門站出口3         121.551294 25.063673
#  [7,] 北投站出口          121.552241 25.062923
#  [8,] 菜寮站出口1         121.544031 25.060889
#  [9,] 菜寮站出口2         121.543143 25.041797
# [10,] 菜寮站出口3         121.543422 25.041355
# [11,] 大安森林公園站出口1 121.544806 25.041467
# [12,] 大安森林公園站出口2 121.54506  25.041772
# [13,] 大安森林公園站出口3 121.543985 25.04202
# [14,] 大安森林公園站出口4 121.541949 25.033508
# [15,] 大安森林公園站出口5 121.541826 25.033515
# [16,] 大安森林公園站出口6 121.54233  25.033241
# [17,] 大安站出口1         121.544057 25.033066
# [18,] 大安站出口2         121.543719 25.032862
# [19,] 大安站出口3         121.543749 25.034006
# [20,] 大安站出口4         121.543636 25.026154
# [21,] 大安站出口5         121.552737 25.023852
# [22,] 大安站出口6         121.558606 25.018554
# ...

# %%
nrow(MRT_station_data)
# Out:
# [1] 363

# %%
write.table(MRT_station_data,file="final_dataset/MRT_station_data.csv")

# %% [markdown]
# # 公車

# %%
bus.df <- fromJSON("Path_with_all_stop.json")

# %%
head(bus.df, 10)
# Out:
# $`11821`
# $`11821`$departureZh
# [1] "永春高中"
#
# $`11821`$name
# [1] "永春高中<->大直美麗華"
#
# $`11821`$destinationZh
# [1] "大直美麗華"
#
# $`11821`$number
# [1] "33"
#
# $`11821`$routeId
# [1] 11821
#
# $`11821`$path
#                  nameZh stopLocationId seqNo                          address
# 1              永春高中           2071     0 松山路大都會客運松職站停車場對面
# 2        松山商職(松山)          15118     1                  松山路641號同向
# 3                國業里           3947     2               信義路六段79號同向
# 4            國稅局宿舍           2143     3                信義路六段3號同向
# 5              松平路口           2102     4                  松仁路454號同向
# 6        信義國中(松仁)           6724     5                  松仁路155號對向
# 7        吳興國小(莊敬)          50152     6                  松仁路227號同向
# 8        信義國中(莊敬)        1000143     7                  莊敬路391巷同巷
# 9          臺北醫學大學           7004     8                  莊敬路309號同向
# 10               景新里           2162     9                  莊敬路251號同向
# ...

# %%
for( i in 1:length(bus.df)){
#     print(i)
    print(bus.df[[i]]$path)
}
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
bus_data_df <- data.frame() 
total.length <- 0

# %%
bus_data_df
# Out:
# <0 x 0 matrix>

# %%
for( i in 1:length(bus.df)){
#     print(i)
    total.length <- total.length + nrow(bus.df[[i]]$path)
    bus_data_df <- rbind(bus_data_df, bus.df[[i]]$path)
}

# %%
nrow(bus.df[[2]]$path)
# Out:
# [1] 69

# %%
69 + 66
# Out:
# [1] 135

# %%
nrow(bus_data_df)
# Out:
# [1] 27651

# %%
total.length
# Out:
# [1] 27651

# %%
write.table(bus_data_df,file="final_dataset/bus_station_data.csv")

# %% [markdown]
# # 便利商店

# %%
stores.df <- fromJSON("store.json")

# %%
nrow(stores.df)
# Out:
# [1] 16166

# %%
values <- c()

# %%
length(values)
# Out:
# [1] 0

# %%
lat.vector <- c()
lng.vector <- c()
number.vector <- c()

# %%
lat.vector
# Out:
# NULL

# %%
lng.vector
# Out:
# NULL

# %%
number.vector
# Out:
# NULL

# %%
store.result.df <- fromJSON("store.json")

# %%
city.taipei.logic <- c()

# %%
for( i in 1:(nrow(store.result.df))){
#     print(2*i-1)
    city.taipei.logic <<- append(city.taipei.logic, grepl("臺北", store.result.df$分公司地址[[i]]))
}

# %%
city.taipei.logic
# Out:
#     [1]  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE
#    [37] FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
#    [49] FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE
#    [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [73] FALSE  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE FALSE
#    [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
#    [97]  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [109] FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
#   [121] FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
#   [133] FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
store.result.df$taipei.logic <- city.taipei.logic

# %%
taipei.store <- store.result.df[store.result.df$taipei.logic == TRUE,]

# %%
nrow(taipei.store)
# Out:
# [1] 2629

# %%
taipei.store
# Out:
#       公司統一編號 公司名稱               分公司統一編號 分公司名稱
# 1     22555003     統一超商股份有限公司   01846195       台北市第一七０分公司
# 2     22555003     統一超商股份有限公司   16080140       台北巿第三四二分公司
# 33    22555003     統一超商股份有限公司   16082148       台北巿第二二四分公司
# 36    22555003     統一超商股份有限公司   16082175       台北巿第２３３分公司
# 42    22555003     統一超商股份有限公司   16082787       台北巿第３４３分公司
# 54    22555003     統一超商股份有限公司   16083723       台北巿第２３７分公司
# 55    22555003     統一超商股份有限公司   16083738       台北巿第２１３分公司
# 74    22555003     統一超商股份有限公司   16085004       台北巿第３４４分公司
# 79    22555003     統一超商股份有限公司   16085237       台北市第３３１分公司
# 80    22555003     統一超商股份有限公司   16085243       台北市第３４５分公司
# 81    22555003     統一超商股份有限公司   16085258       台北市第３４６分公司
# 96    22555003     統一超商股份有限公司   16086926       台北巿第３４７分公司
# 97    22555003     統一超商股份有限公司   16086931       台北巿第３４８分公司
# 99    22555003     統一超商股份有限公司   16087241       台北巿第三四九分公司
# 114   22555003     統一超商股份有限公司   16088760       台北巿第３５０分公司
# ...

# %%
length(taipei.store$分公司地址)
# Out:
# [1] 2629

# %% [markdown]
# ## 先做700個

# %%
for(i in 1:700){
    url <- paste0("https://maps.googleapis.com/maps/api/geocode/json?address=", taipei.store$分公司地址[i], "&key=AIzaSyDP9auxfo9j883Dk66eSGuokqiIVk82LN4")
#     print(stores.df$分公司地址[i])
    store.result <- GET(url)
    store.json <- content(store.result, "parsed")
    store.json$results[[1]]$geometry$location$lat
    lat.vector <<- append(lat.vector, store.json$results[[1]]$geometry$location$lat)
    lng.vector <<- append(lng.vector, store.json$results[[1]]$geometry$location$lng)
    cat(c("第", i ,"次 : ", "lat" , store.json$results[[1]]$geometry$location$lat, "  lng", store.json$results[[1]]$geometry$location$lng, "\n"))
}
# Out:
# 第 1 次 :  lat 25.0895031   lng 121.5267905
# 第 2 次 :  lat 25.0538382   lng 121.5610997
# 第 3 次 :  lat 25.0625757   lng 121.5435127
# 第 4 次 :  lat 22.6233681   lng 120.5445223
# 第 5 次 :  lat 25.0581224   lng 121.5358553
# 第 6 次 :  lat 25.027249   lng 121.5637452
# 第 7 次 :  lat 25.0508746   lng 121.5346609
# 第 8 次 :  lat 25.1191098   lng 121.5288971
# 第 9 次 :  lat 25.0546678   lng 121.5253106
# 第 10 次 :  lat 25.0571989   lng 121.522495
# 第 11 次 :  lat 25.0340846   lng 121.4930782
# 第 12 次 :  lat 25.0626036   lng 121.5200647
# 第 13 次 :  lat 25.1284955   lng 121.4720103
# 第 14 次 :  lat 25.080023   lng 121.51324
# 第 15 次 :  lat 25.023535   lng 121.5429266
# 第 16 次 :  lat 25.109518   lng 121.5193952
# 第 17 次 :  lat 25.053477   lng 121.543845
# 第 18 次 :  lat 25.0514132   lng 121.5480413
# 第 19 次 :  lat 25.0847534   lng 121.4668591
# 第 20 次 :  lat 25.0888155   lng 121.645766
# 第 21 次 :  lat 24.9927198   lng 121.5440414
# 第 22 次 :  lat 25.0482515   lng 121.5405557
# ...

# %%
length(lng.vector)
# Out:
# [1] 696

# %%
write.table(lat.vector,file="final_dataset/store_lat_1-700.csv")

# %%
write.table(lng.vector,file="final_dataset/store_lng_1-700.csv")

# %%
lat.vector_700_1400 <- c()
lng.vector_700_1400 <- c()

# %%
for(i in 701:1400){
    url <- paste0("https://maps.googleapis.com/maps/api/geocode/json?address=", taipei.store$分公司地址[i], "&key=AIzaSyDP9auxfo9j883Dk66eSGuokqiIVk82LN4")
#     print(stores.df$分公司地址[i])
    store.result <- GET(url)
    store.json <- content(store.result, "parsed")
    store.json$results[[1]]$geometry$location$lat
    lat.vector_700_1400 <<- append(lat.vector, store.json$results[[1]]$geometry$location$lat)
    lng.vector_700_1400 <<- append(lng.vector, store.json$results[[1]]$geometry$location$lng)
    cat(c("第", i ,"次 : ", "lat" , store.json$results[[1]]$geometry$location$lat, "  lng", store.json$results[[1]]$geometry$location$lng, "\n"))
}
# Out:
# 第 701 次 :  lat 25.0694833   lng 121.5749558
# 第 702 次 :  lat 25.0780514   lng 121.5705806
# 第 703 次 :  lat 25.053742   lng 121.537309
# 第 704 次 :  lat 25.0548895   lng 121.5213932
# 第 705 次 :  lat 25.043098   lng 121.5682983
# 第 706 次 :  lat 25.0518053   lng 121.5579137
# 第 707 次 :  lat 25.0579011   lng 121.5243957
# 第 708 次 :  lat 25.0602446   lng 121.5303732
# 第 709 次 :  lat 25.117512   lng 121.5224672
# 第 710 次 :  lat 25.1039515   lng 121.5267463
# 第 711 次 :  lat 25.0352175   lng 121.5253491
# 第 712 次 :  lat 24.9873313   lng 121.5761281
# 第 713 次 :  lat 25.0739879   lng 121.576059
# 第 714 次 :  lat 25.03443   lng 121.5501286
# 第 715 次 :  lat 25.0839915   lng 121.5111978
# 第 716 次 :  lat 25.0132497   lng 121.5411187
# 第 717 次 :  lat 25.1191056   lng 121.4661666
# 第 718 次 :  lat 25.0233488   lng 121.5464718
# 第 719 次 :  lat 25.1087479   lng 121.5244427
# 第 720 次 :  lat 25.0524298   lng 121.5484124
# 第 721 次 :  lat 25.066155   lng 121.539345
# ...

# %%
length(lng.vector)
# Out:
# [1] 696

# %%
write.table(lat.vector,file="final_dataset/store_lat_701-1400.csv")
write.table(lng.vector,file="final_dataset/store_lng_701-1400.csv")

# %%
lat.vector_1400_end <- c()
lng.vector_1400_end <- c()

# %%
for(i in 1401:2629){
    url <- paste0("https://maps.googleapis.com/maps/api/geocode/json?address=", taipei.store$分公司地址[i], "&key=AIzaSyDP9auxfo9j883Dk66eSGuokqiIVk82LN4")
#     print(stores.df$分公司地址[i])
    store.result <- GET(url)
    store.json <- content(store.result, "parsed")
    store.json$results[[1]]$geometry$location$lat
    lat.vector_1400_end <<- append(lat.vector, store.json$results[[1]]$geometry$location$lat)
    lng.vector_1400_end <<- append(lng.vector, store.json$results[[1]]$geometry$location$lng)
    cat(c("第", i ,"次 : ", "lat" , store.json$results[[1]]$geometry$location$lat, "  lng", store.json$results[[1]]$geometry$location$lng, "\n"))
}
# Out:
# 第 1401 次 :  lat 25.0547848   lng 121.5406529
# 第 1402 次 :  lat 25.0777903   lng 121.590121
# 第 1403 次 :  lat 25.0447223   lng 121.5485047
# 第 1404 次 :  lat 25.062994   lng 121.566173
# 第 1405 次 :  lat 25.0690948   lng 121.6152236
# 第 1406 次 :  lat 25.070556   lng 121.510989
# 第 1407 次 :  lat 25.044481   lng 121.5752077
# 第 1408 次 :  lat 25.0385475   lng 121.5539682
# 第 1409 次 :  lat 25.024372   lng 121.5537648
# 第 1410 次 :  lat 25.1228327   lng 121.5267962
# 第 1411 次 :  lat 25.0468978   lng 121.5406126
# 第 1412 次 :  lat 25.036982   lng 121.4992842
# 第 1413 次 :  lat 25.0581765   lng 121.5289611
# 第 1414 次 :  lat 24.9815699   lng 121.55982
# 第 1415 次 :  lat 25.0193702   lng 121.5737728
# 第 1416 次 :  lat 25.0508019   lng 121.5183101
# 第 1417 次 :  lat 25.0552547   lng 121.5166868
# 第 1418 次 :  lat 25.115751   lng 121.5152365
# 第 1419 次 :  lat 25.0361892   lng 121.6170517
# 第 1420 次 :  lat 25.0298399   lng 121.530477
# 第 1421 次 :  lat 25.0536413   lng 121.5152652
# ...

# %%
write.table(lat.vector,file="final_dataset/store_lat_1401-2629.csv")
write.table(lng.vector,file="final_dataset/store_lng_1401-2629.csv")

# %%
a = read.table("final_dataset/store_lat_1-700.csv")
b = read.table("final_dataset/store_lng_1-700.csv")
c = read.table("final_dataset/store_lat_701-1400.csv")
d = read.table("final_dataset/store_lng_701-1400.csv")
e = read.table("final_dataset/store_lat_1401-2629.csv")
f = read.table("final_dataset/store_lng_1401-2629.csv")

# %%
a.vector <- as.vector(a$x)
b.vector <- as.vector(b$x)
c.vector <- as.vector(c$x)
d.vector <- as.vector(d$x)
e.vector <- as.vector(e$x)
f.vector <- as.vector(f$x)

# %%
mid.lat <- append(a.vector, c.vector)
final.lat <- append(mid.lat, e.vector)

# %%
mid.lng <- append(b.vector, d.vector)
final.lng <- append(mid.lng, f.vector)

# %%
final.store.data <- cbind(lat = final.lat, lng = final.lng)

# %%
final.store.data
# Out:
#       lat      lng
#  [1,] 25.08950 121.5268
#  [2,] 25.05384 121.5611
#  [3,] 25.06258 121.5435
#  [4,] 22.62337 120.5445
#  [5,] 25.05812 121.5359
#  [6,] 25.02725 121.5637
#  [7,] 25.05087 121.5347
#  [8,] 25.11911 121.5289
#  [9,] 25.05467 121.5253
# [10,] 25.05720 121.5225
# [11,] 25.03408 121.4931
# [12,] 25.06260 121.5201
# [13,] 25.12850 121.4720
# [14,] 25.08002 121.5132
# [15,] 25.02353 121.5429
# [16,] 25.10952 121.5194
# [17,] 25.05348 121.5438
# [18,] 25.05141 121.5480
# [19,] 25.08475 121.4669
# [20,] 25.08882 121.6458
# [21,] 24.99272 121.5440
# [22,] 25.04825 121.5406
# [23,] 25.06489 121.6323
# [24,] 25.06454 121.6420
# [25,] 25.11191 121.5278
# [26,] 25.04990 121.5757
# [27,] 25.03080 121.5459
# [28,] 25.10975 121.5347
# [29,] 25.03611 121.5443
# [30,] 25.06817 121.6638
# [31,] ⋮        ⋮
# [32,] 25.02537 121.5496
# [33,] 24.99161 121.5741
# [34,] 25.03432 121.5607
# [35,] 25.08466 121.5924
# [36,] 25.06826 121.5929
# [37,] 25.08857 121.5038
# ...

# %%
write.table(final.store.data,file="final_dataset/store_all.csv")
